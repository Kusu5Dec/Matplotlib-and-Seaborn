# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#plt.style.use('classic')
##http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.11659534, 0.4966867 , 0.07033277, 0.48169642, 0.43300907,
#        0.0740763 , 0.26584691, 0.85225552, 0.68561531, 0.5829461 ,
#        0.63620062, 0.22670315, 0.72128824, 0.88768365, 0.71987112,
#        0.03963223, 0.84316169, 0.52553689, 0.5547453 , 0.36035135,
#        0.84562306, 0.72768473, 0.26383559, 0.65149223, 0.56660559,
#        0.1250753 , 0.90646188, 0.85590151, 0.50889142, 0.14383379,
#        0.23448949, 0.01513074, 0.13546389, 0.09178603, 0.0229238 ,
#        0.06689733, 0.07978425, 0.17892991, 0.07438709, 0.50859539,
#        0.35775544, 0.35149921, 0.00407044, 0.22968379, 0.50803021,
#        0.28683987, 0.14425026, 0.57703562, 0.18941084, 0.52600239])

# %%
y
# Out:
# array([0.83667872, 0.49112512, 0.86420648, 0.25309369, 0.86883276,
#        0.72508325, 0.15948619, 0.26851961, 0.24967348, 0.10723382,
#        0.53843206, 0.71538191, 0.81389182, 0.79739252, 0.04749575,
#        0.18219335, 0.42831586, 0.16837807, 0.62519582, 0.09589694,
#        0.59378024, 0.48431521, 0.011889  , 0.11946353, 0.17857839,
#        0.51411883, 0.31075358, 0.2712259 , 0.84816585, 0.68743342,
#        0.85638473, 0.82839345, 0.66270044, 0.86567073, 0.75564502,
#        0.86026365, 0.50684099, 0.56941096, 0.75940003, 0.7634252 ,
#        0.786437  , 0.95938741, 0.77647453, 0.67081284, 0.95260944,
#        0.32459424, 0.8143281 , 0.0804476 , 0.52604102, 0.04996715])

# %%
plt.scatter(x,y)

# %%
df=pd.DataFrame(np.random.rand(1000),columns=['data'],index=pd.date_range('2020/05/20',periods=1000))

# %%
df
# Out:
#                 data
# 2020-05-20  0.899885
# 2020-05-21  0.638777
# 2020-05-22  0.221081
# 2020-05-23  0.918033
# 2020-05-24  0.199959
# ...              ...
# 2023-02-09  0.578040
# 2023-02-10  0.006288
# 2023-02-11  0.319011
# 2023-02-12  0.876360
# 2023-02-13  0.909094
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
x=np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x),'--')

# %%
plt.plot(x,np.sin(x),'.-')

# %%
plt.plot(x,np.sin(x),':')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,np.cos(x+1))
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x-0),color='red')

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.plot(x,np.sin(x-1),color='blue')

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color=(1.0,0.5,0))

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.title("This is sin plot before real dataset exectution basic syntax")
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='red')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.title("This is sin plot before real dataset exectution basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='blue',label='Sinx')
plt.plot(x,np.cos(x-0),color='red',label='Cosx')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid()
plt.title("This is sin plot before real dataset exectution basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
#plt.axis('equal')
plt.legend()
plt.show()

# %%
# Histogram

# %%
data=np.random.randn(1000)

# %%
data
# Out:
# array([ 2.26444214e+00, -1.01285847e+00,  1.03607152e+00, -1.22057979e+00,
#         8.34134764e-01,  1.92165670e-01, -9.49412624e-01, -8.45542743e-01,
#        -5.37339485e-01,  1.26093867e+00,  5.18558829e-01,  1.99887660e-01,
#        -5.06313721e-01,  9.06539643e-02, -2.95801685e-03, -8.64705218e-02,
#        -1.05750377e+00,  1.50619725e+00,  6.78656034e-01,  1.75903765e+00,
#        -1.95877344e+00, -1.01839192e+00, -2.20897115e-01,  1.25979892e+00,
#         8.74658126e-01, -3.30688620e-01,  7.90727814e-01, -1.97058111e+00,
#         1.09484599e+00, -6.85718015e-01,  9.71778878e-02,  4.68151578e-01,
#        -1.30603896e+00, -2.59958316e+00,  1.61733141e+00, -4.29291207e-01,
#         1.55286220e-01, -5.26921437e-02,  1.16595368e-01,  1.21035918e+00,
#        -9.40096433e-01,  4.57075982e-01, -9.88644550e-03,  2.06903389e+00,
#         7.30275665e-01,  3.87899282e-01, -7.16246863e-01, -1.59333454e+00,
# ...

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data,bins=20,histtype='step')
plt.show()

# %%
plt.hist(data,bins=20,histtype='barstacked',color='red')
plt.show()

# %%
plt.hist(data,bins=20,histtype='bar',color='green')
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([0.83667872, 0.49112512, 0.86420648, 0.25309369, 0.86883276,
#        0.72508325, 0.15948619, 0.26851961, 0.24967348, 0.10723382,
#        0.53843206, 0.71538191, 0.81389182, 0.79739252, 0.04749575,
#        0.18219335, 0.42831586, 0.16837807, 0.62519582, 0.09589694,
#        0.59378024, 0.48431521, 0.011889  , 0.11946353, 0.17857839,
#        0.51411883, 0.31075358, 0.2712259 , 0.84816585, 0.68743342,
#        0.85638473, 0.82839345, 0.66270044, 0.86567073, 0.75564502,
#        0.86026365, 0.50684099, 0.56941096, 0.75940003, 0.7634252 ,
#        0.786437  , 0.95938741, 0.77647453, 0.67081284, 0.95260944,
#        0.32459424, 0.8143281 , 0.0804476 , 0.52604102, 0.04996715])

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='r')
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x
# Out:
# array([0.628324  , 0.81751908, 0.86366562, 0.01411741, 0.86380943,
#        0.41381102, 0.33292049, 0.88921629, 0.52514367, 0.37329122,
#        0.63015437, 0.09524583, 0.92973072, 0.65146168, 0.58106428,
#        0.97257509, 0.29570066, 0.39097005, 0.89702868, 0.54173342,
#        0.59559845, 0.70617195, 0.50057131, 0.49122013, 0.94258633,
#        0.86659906, 0.59454259, 0.61897174, 0.84258401, 0.10042477,
#        0.28827089, 0.12343184, 0.890833  , 0.48287872, 0.22153852,
#        0.98317823, 0.74787241, 0.60558605, 0.89798918, 0.20873619,
#        0.02302568, 0.68100144, 0.15079   , 0.12196241, 0.96373029,
#        0.03936418, 0.84717026, 0.6093851 , 0.91872512, 0.282059  ])

# %%
y
# Out:
# array([0.68709023, 0.91852528, 0.89186198, 0.8289717 , 0.87191537,
#        0.03866859, 0.15114266, 0.46626199, 0.08479197, 0.49104152,
#        0.31918217, 0.68497362, 0.33966914, 0.98612215, 0.11180732,
#        0.35605918, 0.25955961, 0.69885849, 0.06266689, 0.03382164,
#        0.46476966, 0.43055897, 0.01189085, 0.87885086, 0.10303952,
#        0.31593324, 0.40136005, 0.64475298, 0.84615526, 0.98075873,
#        0.67939134, 0.0126115 , 0.86586351, 0.79476566, 0.18561086,
#        0.65409499, 0.05060406, 0.85130578, 0.35501647, 0.84791076,
#        0.0535782 , 0.04519493, 0.58779286, 0.90287929, 0.17364542,
#        0.43635313, 0.00487439, 0.13125343, 0.42207296, 0.61867184])

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='r',alpha=.9,marker="X")
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='r',alpha=.9,marker="*")
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='r',alpha=.1,marker="*")
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='r',alpha=.9,marker="*")
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x=["a","b","c","d"]
y=np.random.rand(4)

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# array([0.49516851, 0.76317932, 0.59360919, 0.97306039])

# %%
x=["a","b","c","d"]
y=[3,4,1,6]

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [3, 4, 1, 6]

# %%
plt.figure(figsize=(6,3))
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(6,3))
plt.bar(x,y,color='g')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(6,3))
plt.bar(x,y,color='#FF5733')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(6,3))
plt.bar(x,y,color='#FF5733')
plt.title("This is my bar plot")
# Out:
# Text(0.5, 1.0, 'This is my bar plot')

# %%
plt.figure(figsize=(6,3))
plt.barh(x,y,color='#FF5733')
plt.title("This is my bar plot")
# Out:
# Text(0.5, 1.0, 'This is my bar plot')

# %%
data=[1,2,3,3,3,3,3,3,4,5,6,7,8,9]
plt.hist(data)
# Out:
# (array([1., 1., 6., 1., 0., 1., 1., 1., 1., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
# 3 d plot

# %%
x=np.random.rand(20)
y=np.random.rand(20)
z=y=np.random.rand(20)
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z,c='#FF5733',alpha=.9)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x
# Out:
# array([0.79448301, 0.06655678, 0.18797458, 0.05407004, 0.13292188,
#        0.70716693, 0.81116764, 0.47046829, 0.141024  , 0.5918815 ,
#        0.78074781, 0.79083174, 0.21473331, 0.78419785, 0.29688471,
#        0.08975475, 0.88913336, 0.99256225, 0.52961235, 0.46522259])

# %%
y
# Out:
# array([0.15967618, 0.7919016 , 0.26531134, 0.56979386, 0.82203393,
#        0.62774066, 0.2313599 , 0.36405081, 0.847325  , 0.65816823,
#        0.06161827, 0.77995997, 0.50014812, 0.79394426, 0.59253271,
#        0.38406633, 0.50423606, 0.23675805, 0.39742174, 0.04863091])

# %%
z
# Out:
# array([0.15967618, 0.7919016 , 0.26531134, 0.56979386, 0.82203393,
#        0.62774066, 0.2313599 , 0.36405081, 0.847325  , 0.65816823,
#        0.06161827, 0.77995997, 0.50014812, 0.79394426, 0.59253271,
#        0.38406633, 0.50423606, 0.23675805, 0.39742174, 0.04863091])

# %%
data=pd.read_csv("Bank_churn.csv")

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.plot.scatter(x='Age',y='Balance')
# insights
# maximum concentration = 25-50
# maximum=40
#minium=0 it is all age present
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
# Age distrubtion

# %%
plt.title("Age distrubtion")
plt.hist(data["Age"],color='green')
plt.show()

plt.title("balance distrubtion")
plt.hist(data["Balance"],color='green')
plt.show()

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
